# %% [markdown]
# BERT MODEL CREATION

# %%
# A dependency of the preprocessing for BERT inputs
# !pip install -q -U tensorflow-text
# !pip install -q tf-models-official
# Out:
#      |████████████████████████████████| 4.9 MB 4.1 MB/s
#      |████████████████████████████████| 462 kB 43.9 MB/s
#      |████████████████████████████████| 2.2 MB 4.2 MB/s
#      |████████████████████████████████| 1.1 MB 51.0 MB/s
#      |████████████████████████████████| 90 kB 6.1 MB/s
#      |████████████████████████████████| 636 kB 19.7 MB/s
#      |████████████████████████████████| 352 kB 47.0 MB/s
#      |████████████████████████████████| 1.2 MB 51.7 MB/s
#      |████████████████████████████████| 47.8 MB 43 kB/s
#      |████████████████████████████████| 43 kB 919 kB/s
#      |████████████████████████████████| 99 kB 7.4 MB/s
#      |████████████████████████████████| 234 kB 42.6 MB/s
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done

# %%
import os
import shutil
import pandas as pd
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_text as text
from official.nlp import optimization  # to create AdamW optimizer
import keras
import numpy as np

import matplotlib.pyplot as plt

from numpy.random import seed
seed(1)
import tensorflow
tensorflow.random.set_seed(4)

tf.get_logger().setLevel('ERROR')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip drive/MyDrive/loan_status
# !unzip drive/MyDrive/loan_status_eval
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: loan_status/1/1_file779.txt
#   inflating: loan_status/1/1_file7790.txt
#   inflating: loan_status/1/1_file7791.txt
#   inflating: loan_status/1/1_file7792.txt
#   inflating: loan_status/1/1_file7793.txt
#  extracting: loan_status/1/1_file7794.txt
#   inflating: loan_status/1/1_file7795.txt
#   inflating: loan_status/1/1_file7796.txt
#   inflating: loan_status/1/1_file7797.txt
#   inflating: loan_status/1/1_file7798.txt
#   inflating: loan_status/1/1_file7799.txt
#   inflating: loan_status/1/1_file78.txt
#   inflating: loan_status/1/1_file780.txt
#   inflating: loan_status/1/1_file7800.txt
#   inflating: loan_status/1/1_file7801.txt
#   inflating: loan_status/1/1_file7802.txt
#   inflating: loan_status/1/1_file7803.txt
#   inflating: loan_status/1/1_file7804.txt
#   inflating: loan_status/1/1_file7805.txt
#   inflating: loan_status/1/1_file7806.txt
#   inflating: loan_status/1/1_file7807.txt
#   inflating: loan_status/1/1_file7808.txt
#   inflating: loan_status/1/1_file7809.txt
#   inflating: loan_status/1/1_file781.txt
#   inflating: loan_status/1/1_file7810.txt
#   inflating: loan_status/1/1_file7811.txt
#   inflating: loan_status/1/1_file7812.txt
#   inflating: loan_status/1/1_file7813.txt
#   inflating: loan_status/1/1_file7814.txt
#   inflating: loan_status/1/1_file7815.txt
#   inflating: loan_status/1/1_file7816.txt
#   inflating: loan_status/1/1_file7817.txt
#   inflating: loan_status/1/1_file7818.txt
#   inflating: loan_status/1/1_file7819.txt
#   inflating: loan_status/1/1_file782.txt
#   inflating: loan_status/1/1_file7820.txt
#   inflating: loan_status/1/1_file7821.txt
#   inflating: loan_status/1/1_file7822.txt
#   inflating: loan_status/1/1_file7823.txt
#   inflating: loan_status/1/1_file7824.txt
#   inflating: loan_status/1/1_file7825.txt
#   inflating: loan_status/1/1_file7826.txt
#   inflating: loan_status/1/1_file7827.txt
#   inflating: loan_status/1/1_file7828.txt
#  extracting: loan_status/1/1_file7829.txt
#   inflating: loan_status/1/1_file783.txt
#   inflating: loan_status/1/1_file7830.txt
#   inflating: loan_status/1/1_file7831.txt
#   inflating: loan_status/1/1_file7832.txt
#   inflating: loan_status/1/1_file7833.txt
#   inflating: loan_status/1/1_file7834.txt
#   inflating: loan_status/1/1_file7835.txt
#   inflating: loan_status/1/1_file7836.txt
#   inflating: loan_status/1/1_file7837.txt
#   inflating: loan_status/1/1_file7838.txt
#   inflating: loan_status/1/1_file7839.txt
#   inflating: loan_status/1/1_file784.txt
#   inflating: loan_status/1/1_file7840.txt
#   inflating: loan_status/1/1_file7841.txt
#   inflating: loan_status/1/1_file7842.txt
#  extracting: loan_status/1/1_file7843.txt
#   inflating: loan_status/1/1_file7844.txt
#   inflating: loan_status/1/1_file7845.txt
#   inflating: loan_status/1/1_file7846.txt
#   inflating: loan_status/1/1_file7847.txt
#   inflating: loan_status/1/1_file7848.txt
#   inflating: loan_status/1/1_file7849.txt
#   inflating: loan_status/1/1_file785.txt
#   inflating: loan_status/1/1_file7850.txt
#   inflating: loan_status/1/1_file7851.txt
#   inflating: loan_status/1/1_file7852.txt
#   inflating: loan_status/1/1_file7853.txt
#   inflating: loan_status/1/1_file7854.txt
#  extracting: loan_status/1/1_file7855.txt
#   inflating: loan_status/1/1_file7856.txt
#   inflating: loan_status/1/1_file7857.txt
#   inflating: loan_status/1/1_file7858.txt
#   inflating: loan_status/1/1_file7859.txt
#   inflating: loan_status/1/1_file786.txt
#   inflating: loan_status/1/1_file7860.txt
#   inflating: loan_status/1/1_file7861.txt
#   inflating: loan_status/1/1_file7862.txt
#   inflating: loan_status/1/1_file7863.txt
#   inflating: loan_status/1/1_file7864.txt
#   inflating: loan_status/1/1_file7865.txt
#   inflating: loan_status/1/1_file7866.txt
#   inflating: loan_status/1/1_file7867.txt
#   inflating: loan_status/1/1_file7868.txt
#   inflating: loan_status/1/1_file7869.txt
#   inflating: loan_status/1/1_file787.txt
#   inflating: loan_status/1/1_file7870.txt
#   inflating: loan_status/1/1_file7871.txt
#   inflating: loan_status/1/1_file7872.txt
#   inflating: loan_status/1/1_file7873.txt
#   inflating: loan_status/1/1_file7874.txt
#   inflating: loan_status/1/1_file7875.txt
#   inflating: loan_status/1/1_file7876.txt
#  extracting: loan_status/1/1_file7877.txt
#   inflating: loan_status/1/1_file7878.txt
#   inflating: loan_status/1/1_file7879.txt
#   inflating: loan_status/1/1_file788.txt
#   inflating: loan_status/1/1_file7880.txt
#   inflating: loan_status/1/1_file7881.txt
#   inflating: loan_status/1/1_file7882.txt
#   inflating: loan_status/1/1_file7883.txt
#   inflating: loan_status/1/1_file7884.txt
#   inflating: loan_status/1/1_file7885.txt
#   inflating: loan_status/1/1_file7886.txt
#   inflating: loan_status/1/1_file7887.txt
#   inflating: loan_status/1/1_file7888.txt
#   inflating: loan_status/1/1_file7889.txt
#   inflating: loan_status/1/1_file789.txt
#   inflating: loan_status/1/1_file7890.txt
#   inflating: loan_status/1/1_file7891.txt
#   inflating: loan_status/1/1_file7892.txt
#  extracting: loan_status/1/1_file7893.txt
#   inflating: loan_status/1/1_file7894.txt
#  extracting: loan_status/1/1_file7895.txt
#   inflating: loan_status/1/1_file7896.txt
#   inflating: loan_status/1/1_file7897.txt
#   inflating: loan_status/1/1_file7898.txt
#   inflating: loan_status/1/1_file7899.txt
#   inflating: loan_status/1/1_file79.txt
#   inflating: loan_status/1/1_file790.txt
#   inflating: loan_status/1/1_file7900.txt
#   inflating: loan_status/1/1_file7901.txt
#   inflating: loan_status/1/1_file7902.txt
#   inflating: loan_status/1/1_file7903.txt
#   inflating: loan_status/1/1_file7904.txt
#   inflating: loan_status/1/1_file7905.txt
#   inflating: loan_status/1/1_file7906.txt
#   inflating: loan_status/1/1_file7907.txt
#   inflating: loan_status/1/1_file7908.txt
#   inflating: loan_status/1/1_file7909.txt
#   inflating: loan_status/1/1_file791.txt
#   inflating: loan_status/1/1_file7910.txt
#   inflating: loan_status/1/1_file7911.txt
#   inflating: loan_status/1/1_file7912.txt
#   inflating: loan_status/1/1_file7913.txt
#   inflating: loan_status/1/1_file7914.txt
#  extracting: loan_status/1/1_file7915.txt
#   inflating: loan_status/1/1_file7916.txt
#   inflating: loan_status/1/1_file7917.txt
#   inflating: loan_status/1/1_file7918.txt
#   inflating: loan_status/1/1_file7919.txt
#   inflating: loan_status/1/1_file792.txt
#   inflating: loan_status/1/1_file7920.txt
#   inflating: loan_status/1/1_file7921.txt
#  extracting: loan_status/1/1_file7922.txt
#   inflating: loan_status/1/1_file7923.txt
#   inflating: loan_status/1/1_file7924.txt
#   inflating: loan_status/1/1_file7925.txt
#   inflating: loan_status/1/1_file7926.txt
#   inflating: loan_status/1/1_file7927.txt
#   inflating: loan_status/1/1_file7928.txt
#   inflating: loan_status/1/1_file7929.txt
#   inflating: loan_status/1/1_file793.txt
#   inflating: loan_status/1/1_file7930.txt
#   inflating: loan_status/1/1_file7931.txt
#   inflating: loan_status/1/1_file7932.txt
#   inflating: loan_status/1/1_file7933.txt
#   inflating: loan_status/1/1_file7934.txt
#   inflating: loan_status/1/1_file7935.txt
#   inflating: loan_status/1/1_file7936.txt
#  extracting: loan_status/1/1_file7937.txt
#   inflating: loan_status/1/1_file7938.txt
#   inflating: loan_status/1/1_file7939.txt
#   inflating: loan_status/1/1_file794.txt
#   inflating: loan_status/1/1_file7940.txt
#   inflating: loan_status/1/1_file7941.txt
#  extracting: loan_status/1/1_file7942.txt
#   inflating: loan_status/1/1_file7943.txt
#  extracting: loan_status/1/1_file7944.txt
#   inflating: loan_status/1/1_file7945.txt
#   inflating: loan_status/1/1_file7946.txt
#   inflating: loan_status/1/1_file7947.txt
#  extracting: loan_status/1/1_file7948.txt
#   inflating: loan_status/1/1_file7949.txt
#   inflating: loan_status/1/1_file795.txt
#   inflating: loan_status/1/1_file7950.txt
#   inflating: loan_status/1/1_file7951.txt
#   inflating: loan_status/1/1_file7952.txt
#   inflating: loan_status/1/1_file7953.txt
#   inflating: loan_status/1/1_file7954.txt
#   inflating: loan_status/1/1_file7955.txt
#   inflating: loan_status/1/1_file7956.txt
#   inflating: loan_status/1/1_file7957.txt
#   inflating: loan_status_eval/1/1_file702.txt
#   inflating: loan_status_eval/1/1_file703.txt
#   inflating: loan_status_eval/1/1_file704.txt
#   inflating: loan_status_eval/1/1_file705.txt
#   inflating: loan_status_eval/1/1_file706.txt
#   inflating: loan_status_eval/1/1_file707.txt
#   inflating: loan_status_eval/1/1_file708.txt
#  extracting: loan_status_eval/1/1_file709.txt
#   inflating: loan_status_eval/1/1_file71.txt
#   inflating: loan_status_eval/1/1_file710.txt
#   inflating: loan_status_eval/1/1_file711.txt
#   inflating: loan_status_eval/1/1_file712.txt
#   inflating: loan_status_eval/1/1_file713.txt
#   inflating: loan_status_eval/1/1_file714.txt
#   inflating: loan_status_eval/1/1_file715.txt
#   inflating: loan_status_eval/1/1_file716.txt
#   inflating: loan_status_eval/1/1_file717.txt
#   inflating: loan_status_eval/1/1_file718.txt
#   inflating: loan_status_eval/1/1_file719.txt
#   inflating: loan_status_eval/1/1_file72.txt
#   inflating: loan_status_eval/1/1_file720.txt
#   inflating: loan_status_eval/1/1_file721.txt
#   inflating: loan_status_eval/1/1_file722.txt
#   inflating: loan_status_eval/1/1_file723.txt
#   inflating: loan_status_eval/1/1_file724.txt
#   inflating: loan_status_eval/1/1_file725.txt
#   inflating: loan_status_eval/1/1_file726.txt
#   inflating: loan_status_eval/1/1_file727.txt
#   inflating: loan_status_eval/1/1_file728.txt
#   inflating: loan_status_eval/1/1_file729.txt
#   inflating: loan_status_eval/1/1_file73.txt
#   inflating: loan_status_eval/1/1_file730.txt
#   inflating: loan_status_eval/1/1_file731.txt
#  extracting: loan_status_eval/1/1_file732.txt
#   inflating: loan_status_eval/1/1_file733.txt
#   inflating: loan_status_eval/1/1_file734.txt
#   inflating: loan_status_eval/1/1_file735.txt
#   inflating: loan_status_eval/1/1_file736.txt
#   inflating: loan_status_eval/1/1_file737.txt
#   inflating: loan_status_eval/1/1_file738.txt
#   inflating: loan_status_eval/1/1_file739.txt
#   inflating: loan_status_eval/1/1_file74.txt
#   inflating: loan_status_eval/1/1_file740.txt
#   inflating: loan_status_eval/1/1_file741.txt
#   inflating: loan_status_eval/1/1_file742.txt
#   inflating: loan_status_eval/1/1_file743.txt
#  extracting: loan_status_eval/1/1_file744.txt
#   inflating: loan_status_eval/1/1_file745.txt
#   inflating: loan_status_eval/1/1_file746.txt
#   inflating: loan_status_eval/1/1_file747.txt
#   inflating: loan_status_eval/1/1_file748.txt
#   inflating: loan_status_eval/1/1_file749.txt
#   inflating: loan_status_eval/1/1_file75.txt
#   inflating: loan_status_eval/1/1_file750.txt
#   inflating: loan_status_eval/1/1_file751.txt
#   inflating: loan_status_eval/1/1_file752.txt
#   inflating: loan_status_eval/1/1_file753.txt
#   inflating: loan_status_eval/1/1_file754.txt
#  extracting: loan_status_eval/1/1_file755.txt
#   inflating: loan_status_eval/1/1_file756.txt
#   inflating: loan_status_eval/1/1_file757.txt
#   inflating: loan_status_eval/1/1_file758.txt
#   inflating: loan_status_eval/1/1_file759.txt
#   inflating: loan_status_eval/1/1_file76.txt
#  extracting: loan_status_eval/1/1_file760.txt
#   inflating: loan_status_eval/1/1_file761.txt
#   inflating: loan_status_eval/1/1_file762.txt
#  extracting: loan_status_eval/1/1_file763.txt
#   inflating: loan_status_eval/1/1_file764.txt
#   inflating: loan_status_eval/1/1_file765.txt
#   inflating: loan_status_eval/1/1_file766.txt
#   inflating: loan_status_eval/1/1_file767.txt
#   inflating: loan_status_eval/1/1_file768.txt
#   inflating: loan_status_eval/1/1_file769.txt
#   inflating: loan_status_eval/1/1_file77.txt
#   inflating: loan_status_eval/1/1_file770.txt
#   inflating: loan_status_eval/1/1_file771.txt
#   inflating: loan_status_eval/1/1_file772.txt
#   inflating: loan_status_eval/1/1_file773.txt
#   inflating: loan_status_eval/1/1_file774.txt
#   inflating: loan_status_eval/1/1_file775.txt
#   inflating: loan_status_eval/1/1_file776.txt
#   inflating: loan_status_eval/1/1_file777.txt
#   inflating: loan_status_eval/1/1_file778.txt
#   inflating: loan_status_eval/1/1_file779.txt
#  extracting: loan_status_eval/1/1_file78.txt
#   inflating: loan_status_eval/1/1_file780.txt
#   inflating: loan_status_eval/1/1_file781.txt
#   inflating: loan_status_eval/1/1_file782.txt
#   inflating: loan_status_eval/1/1_file783.txt
#   inflating: loan_status_eval/1/1_file784.txt
#   inflating: loan_status_eval/1/1_file785.txt
#   inflating: loan_status_eval/1/1_file786.txt
#   inflating: loan_status_eval/1/1_file787.txt
#   inflating: loan_status_eval/1/1_file788.txt
#   inflating: loan_status_eval/1/1_file789.txt
#   inflating: loan_status_eval/1/1_file79.txt
#   inflating: loan_status_eval/1/1_file790.txt
#   inflating: loan_status_eval/1/1_file791.txt
#   inflating: loan_status_eval/1/1_file792.txt
#   inflating: loan_status_eval/1/1_file793.txt
#   inflating: loan_status_eval/1/1_file794.txt
#   inflating: loan_status_eval/1/1_file795.txt
#   inflating: loan_status_eval/1/1_file796.txt
#   inflating: loan_status_eval/1/1_file797.txt
#   inflating: loan_status_eval/1/1_file798.txt
#   inflating: loan_status_eval/1/1_file799.txt
#   inflating: loan_status_eval/1/1_file8.txt
#   inflating: loan_status_eval/1/1_file80.txt
#   inflating: loan_status_eval/1/1_file800.txt
#   inflating: loan_status_eval/1/1_file801.txt
#   inflating: loan_status_eval/1/1_file802.txt
#   inflating: loan_status_eval/1/1_file803.txt
#  extracting: loan_status_eval/1/1_file804.txt
#   inflating: loan_status_eval/1/1_file805.txt
#   inflating: loan_status_eval/1/1_file806.txt
#   inflating: loan_status_eval/1/1_file807.txt
#   inflating: loan_status_eval/1/1_file808.txt
#   inflating: loan_status_eval/1/1_file809.txt
#   inflating: loan_status_eval/1/1_file81.txt
#   inflating: loan_status_eval/1/1_file810.txt
#   inflating: loan_status_eval/1/1_file811.txt
#   inflating: loan_status_eval/1/1_file812.txt
#   inflating: loan_status_eval/1/1_file813.txt
#   inflating: loan_status_eval/1/1_file814.txt
#   inflating: loan_status_eval/1/1_file815.txt
#   inflating: loan_status_eval/1/1_file816.txt
#   inflating: loan_status_eval/1/1_file817.txt
#   inflating: loan_status_eval/1/1_file818.txt
#   inflating: loan_status_eval/1/1_file819.txt
#   inflating: loan_status_eval/1/1_file82.txt
#   inflating: loan_status_eval/1/1_file820.txt
#   inflating: loan_status_eval/1/1_file821.txt
#   inflating: loan_status_eval/1/1_file822.txt
#   inflating: loan_status_eval/1/1_file823.txt
#   inflating: loan_status_eval/1/1_file824.txt
#   inflating: loan_status_eval/1/1_file825.txt
#   inflating: loan_status_eval/1/1_file826.txt
#   inflating: loan_status_eval/1/1_file827.txt
#   inflating: loan_status_eval/1/1_file828.txt
#   inflating: loan_status_eval/1/1_file829.txt
#   inflating: loan_status_eval/1/1_file83.txt
#   inflating: loan_status_eval/1/1_file830.txt
#   inflating: loan_status_eval/1/1_file831.txt
#   inflating: loan_status_eval/1/1_file832.txt
#   inflating: loan_status_eval/1/1_file833.txt
#   inflating: loan_status_eval/1/1_file834.txt
#   inflating: loan_status_eval/1/1_file835.txt
#   inflating: loan_status_eval/1/1_file836.txt
#   inflating: loan_status_eval/1/1_file837.txt
#   inflating: loan_status_eval/1/1_file838.txt
#   inflating: loan_status_eval/1/1_file839.txt
#   inflating: loan_status_eval/1/1_file84.txt
#   inflating: loan_status_eval/1/1_file840.txt
#   inflating: loan_status_eval/1/1_file841.txt
#   inflating: loan_status_eval/1/1_file842.txt
#  extracting: loan_status_eval/1/1_file843.txt
#   inflating: loan_status_eval/1/1_file844.txt
#   inflating: loan_status_eval/1/1_file845.txt
#   inflating: loan_status_eval/1/1_file846.txt
#   inflating: loan_status_eval/1/1_file847.txt
#   inflating: loan_status_eval/1/1_file848.txt
#   inflating: loan_status_eval/1/1_file849.txt
#   inflating: loan_status_eval/1/1_file85.txt
#   inflating: loan_status_eval/1/1_file850.txt
#   inflating: loan_status_eval/1/1_file851.txt
#   inflating: loan_status_eval/1/1_file852.txt
#   inflating: loan_status_eval/1/1_file853.txt
#   inflating: loan_status_eval/1/1_file854.txt
#   inflating: loan_status_eval/1/1_file855.txt
#   inflating: loan_status_eval/1/1_file856.txt
#   inflating: loan_status_eval/1/1_file857.txt
#   inflating: loan_status_eval/1/1_file858.txt
#   inflating: loan_status_eval/1/1_file859.txt
#   inflating: loan_status_eval/1/1_file86.txt
#   inflating: loan_status_eval/1/1_file860.txt
#   inflating: loan_status_eval/1/1_file861.txt
#   inflating: loan_status_eval/1/1_file862.txt
#   inflating: loan_status_eval/1/1_file863.txt
#   inflating: loan_status_eval/1/1_file864.txt
#   inflating: loan_status_eval/1/1_file865.txt
#   inflating: loan_status_eval/1/1_file866.txt
#  extracting: loan_status_eval/1/1_file867.txt
#   inflating: loan_status_eval/1/1_file868.txt
#   inflating: loan_status_eval/1/1_file869.txt
#   inflating: loan_status_eval/1/1_file87.txt
#   inflating: loan_status_eval/1/1_file870.txt
#   inflating: loan_status_eval/1/1_file871.txt
#   inflating: loan_status_eval/1/1_file872.txt
#   inflating: loan_status_eval/1/1_file873.txt
#   inflating: loan_status_eval/1/1_file874.txt
#   inflating: loan_status_eval/1/1_file875.txt
#   inflating: loan_status_eval/1/1_file876.txt
#   inflating: loan_status_eval/1/1_file877.txt
#   inflating: loan_status_eval/1/1_file878.txt
#   inflating: loan_status_eval/1/1_file879.txt
#   inflating: loan_status_eval/1/1_file88.txt
#  extracting: loan_status_eval/1/1_file880.txt
#   inflating: loan_status_eval/1/1_file881.txt
#   inflating: loan_status_eval/1/1_file882.txt
#   inflating: loan_status_eval/1/1_file883.txt
#   inflating: loan_status_eval/1/1_file884.txt
#   inflating: loan_status_eval/1/1_file885.txt
#   inflating: loan_status_eval/1/1_file886.txt
#   inflating: loan_status_eval/1/1_file887.txt
#   inflating: loan_status_eval/1/1_file888.txt
#   inflating: loan_status_eval/1/1_file889.txt
#   inflating: loan_status_eval/1/1_file89.txt
#   inflating: loan_status_eval/1/1_file890.txt
#   inflating: loan_status_eval/1/1_file891.txt
#   inflating: loan_status_eval/1/1_file892.txt
#   inflating: loan_status_eval/1/1_file893.txt
#   inflating: loan_status_eval/1/1_file894.txt
#   inflating: loan_status_eval/1/1_file895.txt
#   inflating: loan_status_eval/1/1_file896.txt
#   inflating: loan_status_eval/1/1_file897.txt
#   inflating: loan_status_eval/1/1_file898.txt
#   inflating: loan_status_eval/1/1_file899.txt
#   inflating: loan_status_eval/1/1_file9.txt
#   inflating: loan_status_eval/1/1_file90.txt
#   inflating: loan_status_eval/1/1_file900.txt
#   inflating: loan_status_eval/1/1_file901.txt
#   inflating: loan_status_eval/1/1_file902.txt
#   inflating: loan_status_eval/1/1_file903.txt
#   inflating: loan_status_eval/1/1_file904.txt
#   inflating: loan_status_eval/1/1_file905.txt
#   inflating: loan_status_eval/1/1_file906.txt
#   inflating: loan_status_eval/1/1_file907.txt
#   inflating: loan_status_eval/1/1_file908.txt
#   inflating: loan_status_eval/1/1_file909.txt
#   inflating: loan_status_eval/1/1_file91.txt
#   inflating: loan_status_eval/1/1_file910.txt
#   inflating: loan_status_eval/1/1_file911.txt
#   inflating: loan_status_eval/1/1_file912.txt
#   inflating: loan_status_eval/1/1_file913.txt
#  extracting: loan_status_eval/1/1_file914.txt
#   inflating: loan_status_eval/1/1_file915.txt
#  extracting: loan_status_eval/1/1_file916.txt
#   inflating: loan_status_eval/1/1_file917.txt
#   inflating: loan_status_eval/1/1_file918.txt
#   inflating: loan_status_eval/1/1_file919.txt
#   inflating: loan_status_eval/1/1_file92.txt
#   inflating: loan_status_eval/1/1_file920.txt
#  extracting: loan_status_eval/1/1_file921.txt
#   inflating: loan_status_eval/1/1_file922.txt
#   inflating: loan_status_eval/1/1_file923.txt
#   inflating: loan_status_eval/1/1_file924.txt
#   inflating: loan_status_eval/1/1_file925.txt
#   inflating: loan_status_eval/1/1_file926.txt
#  extracting: loan_status_eval/1/1_file927.txt
#   inflating: loan_status_eval/1/1_file928.txt
#   inflating: loan_status_eval/1/1_file929.txt
#   inflating: loan_status_eval/1/1_file93.txt
#   inflating: loan_status_eval/1/1_file930.txt
#   inflating: loan_status_eval/1/1_file931.txt
#   inflating: loan_status_eval/1/1_file932.txt
#   inflating: loan_status_eval/1/1_file933.txt
#   inflating: loan_status_eval/1/1_file934.txt
#   inflating: loan_status_eval/1/1_file935.txt
#   inflating: loan_status_eval/1/1_file936.txt
#   inflating: loan_status_eval/1/1_file937.txt
#   inflating: loan_status_eval/1/1_file938.txt
#   inflating: loan_status_eval/1/1_file939.txt
#   inflating: loan_status_eval/1/1_file94.txt
#   inflating: loan_status_eval/1/1_file940.txt
#   inflating: loan_status_eval/1/1_file941.txt
#   inflating: loan_status_eval/1/1_file942.txt
#   inflating: loan_status_eval/1/1_file943.txt
#   inflating: loan_status_eval/1/1_file944.txt
#   inflating: loan_status_eval/1/1_file945.txt
#   inflating: loan_status_eval/1/1_file946.txt
#   inflating: loan_status_eval/1/1_file947.txt
#   inflating: loan_status_eval/1/1_file948.txt
#   inflating: loan_status_eval/1/1_file949.txt
#   inflating: loan_status_eval/1/1_file95.txt
#   inflating: loan_status_eval/1/1_file950.txt
#   inflating: loan_status_eval/1/1_file951.txt
#   inflating: loan_status_eval/1/1_file952.txt
#   inflating: loan_status_eval/1/1_file953.txt
#   inflating: loan_status_eval/1/1_file954.txt
#   inflating: loan_status_eval/1/1_file955.txt
#  extracting: loan_status_eval/1/1_file956.txt
#  extracting: loan_status_eval/1/1_file957.txt
#   inflating: loan_status_eval/1/1_file958.txt
#   inflating: loan_status_eval/1/1_file959.txt
#   inflating: loan_status_eval/1/1_file96.txt
#   inflating: loan_status_eval/1/1_file960.txt
#   inflating: loan_status_eval/1/1_file961.txt
#   inflating: loan_status_eval/1/1_file962.txt
#   inflating: loan_status_eval/1/1_file963.txt
#   inflating: loan_status_eval/1/1_file964.txt
#   inflating: loan_status_eval/1/1_file965.txt
#   inflating: loan_status_eval/1/1_file966.txt
#   inflating: loan_status_eval/1/1_file967.txt
#   inflating: loan_status_eval/1/1_file968.txt
#   inflating: loan_status_eval/1/1_file969.txt
#   inflating: loan_status_eval/1/1_file97.txt
#   inflating: loan_status_eval/1/1_file970.txt
#   inflating: loan_status_eval/1/1_file971.txt
#   inflating: loan_status_eval/1/1_file972.txt
#   inflating: loan_status_eval/1/1_file973.txt
#   inflating: loan_status_eval/1/1_file974.txt
#   inflating: loan_status_eval/1/1_file975.txt
#   inflating: loan_status_eval/1/1_file976.txt
#   inflating: loan_status_eval/1/1_file977.txt
#   inflating: loan_status_eval/1/1_file978.txt
#   inflating: loan_status_eval/1/1_file979.txt
#   inflating: loan_status_eval/1/1_file98.txt
#   inflating: loan_status_eval/1/1_file980.txt
#   inflating: loan_status_eval/1/1_file981.txt
#   inflating: loan_status_eval/1/1_file982.txt
#   inflating: loan_status_eval/1/1_file983.txt
#   inflating: loan_status_eval/1/1_file984.txt
#   inflating: loan_status_eval/1/1_file985.txt
#   inflating: loan_status_eval/1/1_file986.txt
#   inflating: loan_status_eval/1/1_file987.txt
#   inflating: loan_status_eval/1/1_file988.txt
#   inflating: loan_status_eval/1/1_file989.txt
#   inflating: loan_status_eval/1/1_file99.txt
#   inflating: loan_status_eval/1/1_file990.txt
#   inflating: loan_status_eval/1/1_file991.txt
#   inflating: loan_status_eval/1/1_file992.txt
#   inflating: loan_status_eval/1/1_file993.txt
#   inflating: loan_status_eval/1/1_file994.txt
#   inflating: loan_status_eval/1/1_file995.txt
#   inflating: loan_status_eval/1/1_file996.txt
#   inflating: loan_status_eval/1/1_file997.txt
#   inflating: loan_status_eval/1/1_file998.txt
#   inflating: loan_status_eval/1/1_file999.txt

# %%
AUTOTUNE = tf.data.AUTOTUNE
batch_size = 32
seed = 42

raw_train_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'loan_status',
    batch_size=batch_size,
    validation_split=0.2,
    subset='training',
   # label_mode = 'categorical',
    seed=seed)

class_names = raw_train_ds.class_names
train_ds = raw_train_ds.cache().prefetch(buffer_size=AUTOTUNE)

val_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'loan_status',
    batch_size=batch_size,
    validation_split=0.2,
    subset='validation',
   # label_mode = 'categorical',
    seed=seed)

val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

test_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'loan_status_eval',
  #  label_mode = 'categorical',
    batch_size=batch_size
    )

test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 22872 files belonging to 2 classes.
# Using 18298 files for training.
# Found 22872 files belonging to 2 classes.
# Using 4574 files for validation.
# Found 2542 files belonging to 2 classes.

# %%
def findOptimum():
  bert_preprocess_model = hub.KerasLayer(tfhub_handle_preprocess)
  for i in [0.1,0.2,0.3]:
    for learning in [5e-5]:
      def build_classifier_model():
        text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
        preprocessing_layer = hub.KerasLayer(tfhub_handle_preprocess, name='preprocessing')
        encoder_inputs = preprocessing_layer(text_input)
        encoder = hub.KerasLayer(tfhub_handle_encoder, trainable=True, name='BERT_encoder')
        outputs = encoder(encoder_inputs)
        net = outputs['pooled_output']
        net = tf.keras.layers.Dropout(i)(net)
        net = tf.keras.layers.Dense(2, activation='softmax', name='classifier')(net)
        return tf.keras.Model(text_input, net)

      classifier_model = build_classifier_model()

      loss = tf.keras.losses.SparseCategoricalCrossentropy(
      from_logits=False, reduction="auto", name="sparse_categorical_crossentropy"
      )

      metrics = tf.metrics.SparseCategoricalAccuracy()

      epochs = 2
      steps_per_epoch = tf.data.experimental.cardinality(train_ds).numpy()
      num_train_steps = steps_per_epoch * epochs
      num_warmup_steps = int(0.1*num_train_steps)

      init_lr = learning
      optimizer = optimization.create_optimizer(init_lr=init_lr,
                                                num_train_steps=num_train_steps,
                                                num_warmup_steps=num_warmup_steps,
                                                optimizer_type='adamw')
      
      classifier_model.compile(optimizer=optimizer,
                          loss=loss,
                          metrics=metrics)
      print("******************************************************")
      print("dropout rate: ", i)
      print("learning rate: ", learning)
      print(f'Training model with {tfhub_handle_encoder}')
      history = classifier_model.fit(x=train_ds,
                                    validation_data=val_ds,
                                    epochs=epochs)
      
      print("Categorical Accuracy")
      loss, accuracy = classifier_model.evaluate(test_ds)
      print(f'Loss: {loss}')
      print(f'Accuracy: {accuracy}')

# %%
#@title Choose a BERT model to fine-tune small_bert/bert_en_uncased_L-6_H-768_A-12

bert_model_name = 'small_bert/bert_en_uncased_L-6_H-512_A-8'  #@param ["bert_en_uncased_L-12_H-768_A-12", "bert_en_cased_L-12_H-768_A-12", "bert_multi_cased_L-12_H-768_A-12", "small_bert/bert_en_uncased_L-2_H-128_A-2", "small_bert/bert_en_uncased_L-2_H-256_A-4", "small_bert/bert_en_uncased_L-2_H-512_A-8", "small_bert/bert_en_uncased_L-2_H-768_A-12", "small_bert/bert_en_uncased_L-4_H-128_A-2", "small_bert/bert_en_uncased_L-4_H-256_A-4", "small_bert/bert_en_uncased_L-4_H-512_A-8", "small_bert/bert_en_uncased_L-4_H-768_A-12", "small_bert/bert_en_uncased_L-6_H-128_A-2", "small_bert/bert_en_uncased_L-6_H-256_A-4", "small_bert/bert_en_uncased_L-6_H-512_A-8", "small_bert/bert_en_uncased_L-6_H-768_A-12", "small_bert/bert_en_uncased_L-8_H-128_A-2", "small_bert/bert_en_uncased_L-8_H-256_A-4", "small_bert/bert_en_uncased_L-8_H-512_A-8", "small_bert/bert_en_uncased_L-8_H-768_A-12", "small_bert/bert_en_uncased_L-10_H-128_A-2", "small_bert/bert_en_uncased_L-10_H-256_A-4", "small_bert/bert_en_uncased_L-10_H-512_A-8", "small_bert/bert_en_uncased_L-10_H-768_A-12", "small_bert/bert_en_uncased_L-12_H-128_A-2", "small_bert/bert_en_uncased_L-12_H-256_A-4", "small_bert/bert_en_uncased_L-12_H-512_A-8", "small_bert/bert_en_uncased_L-12_H-768_A-12", "albert_en_base", "electra_small", "electra_base", "experts_pubmed", "experts_wiki_books", "talking-heads_base"]

map_name_to_handle = {
    'bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/3',
    'bert_en_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_cased_L-12_H-768_A-12/3',
    'bert_multi_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_multi_cased_L-12_H-768_A-12/3',
    'small_bert/bert_en_uncased_L-2_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-2_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-2_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-2_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-4_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-4_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-4_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-4_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-6_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-6_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-6_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-6_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-8_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-8_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-8_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-8_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-10_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-10_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-10_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-10_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-12_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-12_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-12_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-768_A-12/1',
    'albert_en_base':
        'https://tfhub.dev/tensorflow/albert_en_base/2',
    'electra_small':
        'https://tfhub.dev/google/electra_small/2',
    'electra_base':
        'https://tfhub.dev/google/electra_base/2',
    'experts_pubmed':
        'https://tfhub.dev/google/experts/bert/pubmed/2',
    'experts_wiki_books':
        'https://tfhub.dev/google/experts/bert/wiki_books/2',
    'talking-heads_base':
        'https://tfhub.dev/tensorflow/talkheads_ggelu_bert_en_base/1',
}

map_model_to_preprocess = {
    'bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'bert_en_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_cased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'bert_multi_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_multi_cased_preprocess/3',
    'albert_en_base':
        'https://tfhub.dev/tensorflow/albert_en_preprocess/3',
    'electra_small':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'electra_base':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'experts_pubmed':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'experts_wiki_books':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'talking-heads_base':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
}

tfhub_handle_encoder = map_name_to_handle[bert_model_name]
tfhub_handle_preprocess = map_model_to_preprocess[bert_model_name]

print(f'BERT model selected           : {tfhub_handle_encoder}')
print(f'Preprocess model auto-selected: {tfhub_handle_preprocess}')
# Out:
# BERT model selected           : https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-512_A-8/1
# Preprocess model auto-selected: https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3

# %%
classifier = findOptimum()
# Out:
# ******************************************************
# dropout rate:  0.1
# learning rate:  5e-05
# Training model with https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-512_A-8/1
# Epoch 1/2
# 572/572 [==============================] - 4875s 9s/step - loss: 0.4452 - sparse_categorical_accuracy: 0.8444 - val_loss: 0.4079 - val_sparse_categorical_accuracy: 0.8575
# Epoch 2/2
# 572/572 [==============================] - 4888s 9s/step - loss: 0.4168 - sparse_categorical_accuracy: 0.8542 - val_loss: 0.4003 - val_sparse_categorical_accuracy: 0.8575
# Categorical Accuracy
# 80/80 [==============================] - 186s 2s/step - loss: 0.4183 - sparse_categorical_accuracy: 0.8489
# Loss: 0.41831469535827637
# Accuracy: 0.8489378690719604
# ******************************************************
# dropout rate:  0.2
# learning rate:  5e-05
# Training model with https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-512_A-8/1
# Epoch 1/2
# 572/572 [==============================] - 4931s 9s/step - loss: 0.4619 - sparse_categorical_accuracy: 0.8398 - val_loss: 0.4091 - val_sparse_categorical_accuracy: 0.8575
# Epoch 2/2
# 370/572 [==================>...........] - ETA: 27:10 - loss: 0.4218 - sparse_categorical_accuracy: 0.8549

# %% [markdown]
# ## Training Bert Classifier

# %%
#@title Choose a BERT model to fine-tune

bert_model_name = 'small_bert/bert_en_uncased_L-6_H-512_A-8'  #@param ["bert_en_uncased_L-12_H-768_A-12", "bert_en_cased_L-12_H-768_A-12", "bert_multi_cased_L-12_H-768_A-12", "small_bert/bert_en_uncased_L-2_H-128_A-2", "small_bert/bert_en_uncased_L-2_H-256_A-4", "small_bert/bert_en_uncased_L-2_H-512_A-8", "small_bert/bert_en_uncased_L-2_H-768_A-12", "small_bert/bert_en_uncased_L-4_H-128_A-2", "small_bert/bert_en_uncased_L-4_H-256_A-4", "small_bert/bert_en_uncased_L-4_H-512_A-8", "small_bert/bert_en_uncased_L-4_H-768_A-12", "small_bert/bert_en_uncased_L-6_H-128_A-2", "small_bert/bert_en_uncased_L-6_H-256_A-4", "small_bert/bert_en_uncased_L-6_H-512_A-8", "small_bert/bert_en_uncased_L-6_H-768_A-12", "small_bert/bert_en_uncased_L-8_H-128_A-2", "small_bert/bert_en_uncased_L-8_H-256_A-4", "small_bert/bert_en_uncased_L-8_H-512_A-8", "small_bert/bert_en_uncased_L-8_H-768_A-12", "small_bert/bert_en_uncased_L-10_H-128_A-2", "small_bert/bert_en_uncased_L-10_H-256_A-4", "small_bert/bert_en_uncased_L-10_H-512_A-8", "small_bert/bert_en_uncased_L-10_H-768_A-12", "small_bert/bert_en_uncased_L-12_H-128_A-2", "small_bert/bert_en_uncased_L-12_H-256_A-4", "small_bert/bert_en_uncased_L-12_H-512_A-8", "small_bert/bert_en_uncased_L-12_H-768_A-12", "albert_en_base", "electra_small", "electra_base", "experts_pubmed", "experts_wiki_books", "talking-heads_base"]

map_name_to_handle = {
    'bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/3',
    'bert_en_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_cased_L-12_H-768_A-12/3',
    'bert_multi_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_multi_cased_L-12_H-768_A-12/3',
    'small_bert/bert_en_uncased_L-2_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-2_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-2_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-2_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-2_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-4_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-4_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-4_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-4_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-4_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-6_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-6_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-6_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-6_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-8_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-8_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-8_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-8_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-8_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-10_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-10_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-10_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-10_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-10_H-768_A-12/1',
    'small_bert/bert_en_uncased_L-12_H-128_A-2':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-128_A-2/1',
    'small_bert/bert_en_uncased_L-12_H-256_A-4':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-256_A-4/1',
    'small_bert/bert_en_uncased_L-12_H-512_A-8':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-512_A-8/1',
    'small_bert/bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-12_H-768_A-12/1',
    'albert_en_base':
        'https://tfhub.dev/tensorflow/albert_en_base/2',
    'electra_small':
        'https://tfhub.dev/google/electra_small/2',
    'electra_base':
        'https://tfhub.dev/google/electra_base/2',
    'experts_pubmed':
        'https://tfhub.dev/google/experts/bert/pubmed/2',
    'experts_wiki_books':
        'https://tfhub.dev/google/experts/bert/wiki_books/2',
    'talking-heads_base':
        'https://tfhub.dev/tensorflow/talkheads_ggelu_bert_en_base/1',
}

map_model_to_preprocess = {
    'bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'bert_en_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_cased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-2_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-4_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-6_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-8_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-10_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-128_A-2':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-256_A-4':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-512_A-8':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'small_bert/bert_en_uncased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'bert_multi_cased_L-12_H-768_A-12':
        'https://tfhub.dev/tensorflow/bert_multi_cased_preprocess/3',
    'albert_en_base':
        'https://tfhub.dev/tensorflow/albert_en_preprocess/3',
    'electra_small':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'electra_base':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'experts_pubmed':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'experts_wiki_books':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
    'talking-heads_base':
        'https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3',
}

tfhub_handle_encoder = map_name_to_handle[bert_model_name]
tfhub_handle_preprocess = map_model_to_preprocess[bert_model_name]

print(f'BERT model selected           : {tfhub_handle_encoder}')
print(f'Preprocess model auto-selected: {tfhub_handle_preprocess}')
# Out:
# BERT model selected           : https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-512_A-8/1
# Preprocess model auto-selected: https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3

# %%
def getBestClassifier():
  bert_preprocess_model = hub.KerasLayer(tfhub_handle_preprocess)
  accuracy = 0
  count = 0
  def build_classifier_model():
    text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
    preprocessing_layer = hub.KerasLayer(tfhub_handle_preprocess, name='preprocessing')
    encoder_inputs = preprocessing_layer(text_input)
    encoder = hub.KerasLayer(tfhub_handle_encoder, trainable=True, name='BERT_encoder')
    outputs = encoder(encoder_inputs)
    net = outputs['pooled_output']
    net = tf.keras.layers.Dropout(0.2)(net)
    net = tf.keras.layers.Dense(2, activation='softmax', name='classifier')(net)
    return tf.keras.Model(text_input, net)

  classifier_model = build_classifier_model()

  loss = tf.keras.losses.SparseCategoricalCrossentropy(
  from_logits=False, reduction="auto", name="sparse_categorical_crossentropy"
  )
  metrics = tf.metrics.SparseCategoricalAccuracy()

  epochs = 2
  steps_per_epoch = tf.data.experimental.cardinality(train_ds).numpy()
  num_train_steps = steps_per_epoch * epochs
  num_warmup_steps = int(0.1*num_train_steps)

  init_lr = 5e-5
  optimizer = optimization.create_optimizer(init_lr=init_lr,
                                        num_train_steps=num_train_steps,
                                            num_warmup_steps=num_warmup_steps,
                                      optimizer_type='adamw')
  
  classifier_model.compile(optimizer=optimizer,
                      loss=loss,
                      metrics=metrics)
  print("******************************************************")
  print(f'Training model with {tfhub_handle_encoder}')
  history = classifier_model.fit(x=train_ds,
                                validation_data=val_ds,
                                epochs=epochs)

  loss, accuracy = classifier_model.evaluate(test_ds)
  print(f'Loss: {loss}')
  print(f'Accuracy: {accuracy}')
  count+=1
  saved_classifier_model = classifier_model

  return saved_classifier_model

# %%
classifier_model = getBestClassifier()
# Out:
# ******************************************************
# Training model with https://tfhub.dev/tensorflow/small_bert/bert_en_uncased_L-6_H-512_A-8/1
# Epoch 1/2
# 572/572 [==============================] - 7449s 13s/step - loss: 0.4439 - sparse_categorical_accuracy: 0.8484 - val_loss: 0.4005 - val_sparse_categorical_accuracy: 0.8575
# Epoch 2/2
# 572/572 [==============================] - 7444s 13s/step - loss: 0.4137 - sparse_categorical_accuracy: 0.8550 - val_loss: 0.3975 - val_sparse_categorical_accuracy: 0.8575
# 80/80 [==============================] - 266s 3s/step - loss: 0.4189 - sparse_categorical_accuracy: 0.8489
# Loss: 0.41889339685440063
# Accuracy: 0.8489378690719604

# %% [markdown]
# ## Export for inference
# Save fine-tuned model for later use.

# %%
classifier_model.save("drive/MyDrive/loan_reason_bert")
# Out:
# WARNING:absl:Found untraced functions such as restored_function_body, restored_function_body, restored_function_body, restored_function_body, restored_function_body while saving (showing 5 of 184). These functions will not be directly callable after loading.

# %%
df = pd.read_excel("drive/MyDrive/loan_processed_cleaned.xlsx")

# %%
BERT_predictions = classifier_model.predict(df["cleaned_desc"])

# %%
bert_prediction = []
for i in range(len(BERT_predictions)):
  bert_prediction.append(np.argmax(BERT_predictions[i]))

bert_df = pd.DataFrame()
bert_df["bert_predictions"] = bert_prediction

# %%
bert_df.to_excel("drive/MyDrive/BERT_prediction_loan_status.xlsx")
